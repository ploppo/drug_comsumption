# %% [markdown]
# # Introduzione a Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# ## Inizializzazione di Serie.
#
# ### Tramite array di dati

# %%
x = np.random.rand(10)
x
# Out:
# array([0.64315396, 0.65711712, 0.72067381, 0.30361315, 0.382718  ,
#        0.11428501, 0.53587444, 0.39786061, 0.6037311 , 0.57396239])

# %%
s1 = pd.Series(x, index=[f'index{i}' for i in range(1,11)], name='my_series1')
s2 = pd.Series(x, name='my_series2')

# %%
s1
# Out:
# index1     0.643154
# index2     0.657117
# index3     0.720674
# index4     0.303613
# index5     0.382718
# index6     0.114285
# index7     0.535874
# index8     0.397861
# index9     0.603731
# index10    0.573962
# Name: my_series1, dtype: float64

# %%
s2
# Out:
# 0    0.643154
# 1    0.657117
# 2    0.720674
# 3    0.303613
# 4    0.382718
# 5    0.114285
# 6    0.535874
# 7    0.397861
# 8    0.603731
# 9    0.573962
# Name: my_series2, dtype: float64

# %% [markdown]
# ### Tramite dizionario

# %%
d = {'Age':30, 'Height':185, 'Weight':90}
d
# Out:
# {'Age': 30, 'Height': 185, 'Weight': 90}

# %%
s1d = pd.Series(d)

# %%
s1d
# Out:
# Age        30
# Height    185
# Weight     90
# dtype: int64

# %% [markdown]
# ## Inizializzazione DataFrame
#
# ### Tramite dizionario

# %%
D = {'Float_random':np.random.rand(10), 'Integer_random':np.random.permutation(10)}
D
# Out:
# {'Float_random': array([0.95020556, 0.73815195, 0.72778968, 0.06096872, 0.4001925 ,
#         0.44146095, 0.51515285, 0.89815788, 0.25099793, 0.38807288]),
#  'Integer_random': array([3, 8, 5, 2, 0, 9, 7, 6, 4, 1])}

# %%
df1d = pd.DataFrame(D)
df1d
# Out:
#    Float_random  Integer_random
# 0      0.950206               3
# 1      0.738152               8
# 2      0.727790               5
# 3      0.060969               2
# 4      0.400192               0
# 5      0.441461               9
# 6      0.515153               7
# 7      0.898158               6
# 8      0.250998               4
# 9      0.388073               1

# %%
df1d.dtypes
# Out:
# Float_random      float64
# Integer_random      int32
# dtype: object

# %% [markdown]
# ### Tramite array di dati

# %%
X = np.random.rand(10,5)
X
# Out:
# array([[0.49421099, 0.65078935, 0.8578242 , 0.43448634, 0.38090081],
#        [0.57945468, 0.22837452, 0.67705647, 0.36758983, 0.19398202],
#        [0.79545247, 0.44205636, 0.40909713, 0.78471425, 0.52760551],
#        [0.49174514, 0.38814453, 0.9587181 , 0.76105061, 0.40129822],
#        [0.77224333, 0.98960928, 0.60625711, 0.01254714, 0.7461232 ],
#        [0.25920133, 0.98624382, 0.7237754 , 0.20185569, 0.5030412 ],
#        [0.36244587, 0.53323298, 0.50804316, 0.82667244, 0.21864268],
#        [0.30709907, 0.81849804, 0.29133023, 0.5772758 , 0.21136837],
#        [0.06861234, 0.91104517, 0.98679361, 0.99313058, 0.89834966],
#        [0.93962578, 0.66030525, 0.35096008, 0.27846187, 0.15313895]])

# %%
df1 = pd.DataFrame(X, index=range(1, X.shape[0] + 1), columns=[f'column_{i}' for i in range(1, X.shape[1] + 1)])
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5
# 1   0.494211  0.650789  0.857824  0.434486  0.380901
# 2   0.579455  0.228375  0.677056  0.367590  0.193982
# 3   0.795452  0.442056  0.409097  0.784714  0.527606
# 4   0.491745  0.388145  0.958718  0.761051  0.401298
# 5   0.772243  0.989609  0.606257  0.012547  0.746123
# 6   0.259201  0.986244  0.723775  0.201856  0.503041
# 7   0.362446  0.533233  0.508043  0.826672  0.218643
# 8   0.307099  0.818498  0.291330  0.577276  0.211368
# 9   0.068612  0.911045  0.986794  0.993131  0.898350
# 10  0.939626  0.660305  0.350960  0.278462  0.153139

# %% [markdown]
# ## Estrarre/Aggiungere colonne

# %%
df1['column_2']
# Out:
# 1     0.650789
# 2     0.228375
# 3     0.442056
# 4     0.388145
# 5     0.989609
# 6     0.986244
# 7     0.533233
# 8     0.818498
# 9     0.911045
# 10    0.660305
# Name: column_2, dtype: float64

# %%
df1['column_6'] = np.random.rand(10)
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.494211  0.650789  0.857824  0.434486  0.380901  0.490834
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3   0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4   0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5   0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6   0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %% [markdown]
# ## Attributi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %%
df1.at[6, 'column_2']
# Out:
# 0.9862438164830015

# %%
df1.iat[5, 1]
# Out:
# 0.9862438164830015

# %%
df1.index
# Out:
# RangeIndex(start=1, stop=11, step=1)

# %%
df1.columns
# Out:
# Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')

# %%
df1.axes
# Out:
# [RangeIndex(start=1, stop=11, step=1),
#  Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')]

# %%
df1.loc[[1,7,10], :]
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.494211  0.650789  0.857824  0.434486  0.380901  0.490834
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1.loc[[1,7,10], ['column_1', 'column_3']]
# Out:
#     column_1  column_3
# 1   0.494211  0.857824
# 7   0.362446  0.508043
# 10  0.939626  0.350960

# %%
df1.iloc[[0,6,9],[0,2]]
# Out:
#     column_1  column_3
# 1   0.494211  0.857824
# 7   0.362446  0.508043
# 10  0.939626  0.350960

# %%
df1.loc[(df1.index > 3) & (df1.index <= 7), df1.columns != 'column_3']
# Out:
#    column_1  column_2  column_4  column_5  column_6
# 4  0.491745  0.388145  0.761051  0.401298  0.336536
# 5  0.772243  0.989609  0.012547  0.746123  0.736742
# 6  0.259201  0.986244  0.201856  0.503041  0.905779
# 7  0.362446  0.533233  0.826672  0.218643  0.867372

# %%
df1.shape
# Out:
# (10, 6)

# %%
df1.ndim
# Out:
# 2

# %%
df1.size
# Out:
# 60

# %%
df1.values
# Out:
# array([[0.49421099, 0.65078935, 0.8578242 , 0.43448634, 0.38090081,
#         0.49083434],
#        [0.57945468, 0.22837452, 0.67705647, 0.36758983, 0.19398202,
#         0.14268377],
#        [0.79545247, 0.44205636, 0.40909713, 0.78471425, 0.52760551,
#         0.27599076],
#        [0.49174514, 0.38814453, 0.9587181 , 0.76105061, 0.40129822,
#         0.33653647],
#        [0.77224333, 0.98960928, 0.60625711, 0.01254714, 0.7461232 ,
#         0.73674235],
#        [0.25920133, 0.98624382, 0.7237754 , 0.20185569, 0.5030412 ,
#         0.90577907],
#        [0.36244587, 0.53323298, 0.50804316, 0.82667244, 0.21864268,
#         0.86737246],
#        [0.30709907, 0.81849804, 0.29133023, 0.5772758 , 0.21136837,
#         0.88043686],
#        [0.06861234, 0.91104517, 0.98679361, 0.99313058, 0.89834966,
#         0.9727912 ],
#        [0.93962578, 0.66030525, 0.35096008, 0.27846187, 0.15313895,
#         0.1805584 ]])

# %% [markdown]
# ## Metodi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %% [markdown]
# ### Metodi di Esplorazione

# %%
df1.head(3)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.494211  0.650789  0.857824  0.434486  0.380901  0.490834
# 2  0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3  0.795452  0.442056  0.409097  0.784714  0.527606  0.275991

# %%
df1.tail(2)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column_1  10 non-null     float64
#  1   column_2  10 non-null     float64
#  2   column_3  10 non-null     float64
#  3   column_4  10 non-null     float64
#  4   column_5  10 non-null     float64
#  5   column_6  10 non-null     float64
# dtypes: float64(6)
# memory usage: 546.0 bytes

# %%
df1.nunique()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.nunique(axis=1)
# Out:
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     6
# 10    6
# dtype: int64

# %%
df1.isna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1      False     False     False     False     False     False
# 2      False     False     False     False     False     False
# 3      False     False     False     False     False     False
# 4      False     False     False     False     False     False
# 5      False     False     False     False     False     False
# 6      False     False     False     False     False     False
# 7      False     False     False     False     False     False
# 8      False     False     False     False     False     False
# 9      False     False     False     False     False     False
# 10     False     False     False     False     False     False

# %%
df1.count()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.value_counts()
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.068612  0.911045  0.986794  0.993131  0.898350  0.972791    1
# 0.259201  0.986244  0.723775  0.201856  0.503041  0.905779    1
# 0.307099  0.818498  0.291330  0.577276  0.211368  0.880437    1
# 0.362446  0.533233  0.508043  0.826672  0.218643  0.867372    1
# 0.491745  0.388145  0.958718  0.761051  0.401298  0.336536    1
# 0.494211  0.650789  0.857824  0.434486  0.380901  0.490834    1
# 0.579455  0.228375  0.677056  0.367590  0.193982  0.142684    1
# 0.772243  0.989609  0.606257  0.012547  0.746123  0.736742    1
# 0.795452  0.442056  0.409097  0.784714  0.527606  0.275991    1
# 0.939626  0.660305  0.350960  0.278462  0.153139  0.180558    1
# dtype: int64

# %%
df1.value_counts(normalize=True)
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.068612  0.911045  0.986794  0.993131  0.898350  0.972791    0.1
# 0.259201  0.986244  0.723775  0.201856  0.503041  0.905779    0.1
# 0.307099  0.818498  0.291330  0.577276  0.211368  0.880437    0.1
# 0.362446  0.533233  0.508043  0.826672  0.218643  0.867372    0.1
# 0.491745  0.388145  0.958718  0.761051  0.401298  0.336536    0.1
# 0.494211  0.650789  0.857824  0.434486  0.380901  0.490834    0.1
# 0.579455  0.228375  0.677056  0.367590  0.193982  0.142684    0.1
# 0.772243  0.989609  0.606257  0.012547  0.746123  0.736742    0.1
# 0.795452  0.442056  0.409097  0.784714  0.527606  0.275991    0.1
# 0.939626  0.660305  0.350960  0.278462  0.153139  0.180558    0.1
# dtype: float64

# %% [markdown]
# ### Analisi Statistica di Base e Operazioni su Valori

# %%
df1.describe()
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.507009   0.660830   0.636986   0.523778   0.423445   0.578973
# std     0.270968   0.263960   0.248233   0.315669   0.249840   0.328002
# min     0.068612   0.228375   0.291330   0.012547   0.153139   0.142684
# 25%     0.320936   0.464851   0.433834   0.300744   0.213187   0.291127
# 50%     0.492978   0.655547   0.641657   0.505881   0.391100   0.613788
# 75%     0.724046   0.887908   0.824312   0.778798   0.521464   0.877171
# max     0.939626   0.989609   0.986794   0.993131   0.898350   0.972791

# %%
df1.describe(percentiles=[0.13, 0.87, 0.99])
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.507009   0.660830   0.636986   0.523778   0.423445   0.578973
# std     0.270968   0.263960   0.248233   0.315669   0.249840   0.328002
# min     0.068612   0.228375   0.291330   0.012547   0.153139   0.142684
# 13%     0.267344   0.397310   0.360843   0.214879   0.196938   0.196782
# 50%     0.492978   0.655547   0.641657   0.505881   0.391100   0.613788
# 87%     0.791507   0.973460   0.941566   0.819540   0.708975   0.901471
# 99%     0.926650   0.989306   0.984267   0.978149   0.884649   0.966760
# max     0.939626   0.989609   0.986794   0.993131   0.898350   0.972791

# %%
df1.mean()
# Out:
# column_1    0.507009
# column_2    0.660830
# column_3    0.636986
# column_4    0.523778
# column_5    0.423445
# column_6    0.578973
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 1     0.551508
# 2     0.364857
# 3     0.539153
# 4     0.556249
# 5     0.643920
# 6     0.596649
# 7     0.552735
# 8     0.514335
# 9     0.805120
# 10    0.427175
# dtype: float64

# %%
df1.corr()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  1.000000 -0.320903 -0.478350 -0.468576 -0.283886 -0.750440
# column_2 -0.320903  1.000000  0.017549 -0.318477  0.550212  0.756727
# column_3 -0.478350  0.017549  1.000000  0.220449  0.520800  0.120011
# column_4 -0.468576 -0.318477  0.220449  1.000000  0.122295  0.149837
# column_5 -0.283886  0.550212  0.520800  0.122295  1.000000  0.442443
# column_6 -0.750440  0.756727  0.120011  0.149837  0.442443  1.000000

# %%
df1.cov()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  0.073424 -0.022953 -0.032175 -0.040080 -0.019219 -0.066698
# column_2 -0.022953  0.069675  0.001150 -0.026537  0.036285  0.065517
# column_3 -0.032175  0.001150  0.061620  0.017274  0.032299  0.009771
# column_4 -0.040080 -0.026537  0.017274  0.099647  0.009645  0.015514
# column_5 -0.019219  0.036285  0.032299  0.009645  0.062420  0.036257
# column_6 -0.066698  0.065517  0.009771  0.015514  0.036257  0.107585

# %%
df1.sample(3)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437

# %% [markdown]
# ### Metodi di Trasformazione/Alterazione

# %%
df1_copy = df1.copy()
df1_fakecopy = df1

# %%
df1_fakecopy.at[1, 'column_1'] = 10

# %%
df1_copy.at[1, 'column_1'] = np.nan

# %%
df1_copy
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1        NaN  0.650789  0.857824  0.434486  0.380901  0.490834
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3   0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4   0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5   0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6   0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.650789  0.857824  0.434486  0.380901  0.490834
# 2    0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3    0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4    0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5    0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6    0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7    0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8    0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9    0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10   0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %% [markdown]
# (Notare che la modifica fatta a df1_fakecopy ha modificato anche df1!)

# %%
df1.drop([1, 3], axis=0)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 4   0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5   0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6   0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1_copy.dropna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3   0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4   0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5   0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6   0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1_copy.fillna(1000)
# Out:
#        column_1  column_2  column_3  column_4  column_5  column_6
# 1   1000.000000  0.650789  0.857824  0.434486  0.380901  0.490834
# 2      0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3      0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4      0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5      0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6      0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7      0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8      0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9      0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10     0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1_copy.rename(index={1:'nuovo_index'}, columns={'column_1':'COLONNA_1'})
# Out:
#              COLONNA_1  column_2  column_3  column_4  column_5  column_6
# nuovo_index        NaN  0.650789  0.857824  0.434486  0.380901  0.490834
# 2             0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3             0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4             0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5             0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6             0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7             0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8             0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9             0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10            0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1_copy.reset_index()
# Out:
#    index  column_1  column_2  column_3  column_4  column_5  column_6
# 0      1       NaN  0.650789  0.857824  0.434486  0.380901  0.490834
# 1      2  0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 2      3  0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 3      4  0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 4      5  0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 5      6  0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 6      7  0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 7      8  0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 8      9  0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 9     10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %%
df1_copy.sort_values('column_1')
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 9   0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 6   0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 8   0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 7   0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 4   0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 2   0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 5   0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 3   0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 10  0.939626  0.660305  0.350960  0.278462  0.153139  0.180558
# 1        NaN  0.650789  0.857824  0.434486  0.380901  0.490834

# %% [markdown]
# (Notare il NaN messo in fondo; per maggiori informazioni, guardare la documentazione ufficiale)

# %%
df1.to_csv('df1.csv', columns=['column_1', 'column_5', 'column_2'], index_label='ID')

# %%
df1.to_pickle('df1.pkl')

# %% [markdown]
# ### Metodi di Visualizzazione

# %%
df1_plot = df1.sort_values('column_1')
df1_plot.plot('column_1', ['column_6', 'column_3'])
# Out:
# <AxesSubplot:xlabel='column_1'>

# %%
df1.plot.scatter(x='column_2', y='column_5', c='column_3')
# Out:
# <AxesSubplot:xlabel='column_2', ylabel='column_5'>

# %%
df1.boxplot(column=['column_3', 'column_2'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Caricamento DataFrame

# %%
pd.read_csv('df1.csv')
# Out:
#    ID   column_1  column_5  column_2
# 0   1  10.000000  0.380901  0.650789
# 1   2   0.579455  0.193982  0.228375
# 2   3   0.795452  0.527606  0.442056
# 3   4   0.491745  0.401298  0.388145
# 4   5   0.772243  0.746123  0.989609
# 5   6   0.259201  0.503041  0.986244
# 6   7   0.362446  0.218643  0.533233
# 7   8   0.307099  0.211368  0.818498
# 8   9   0.068612  0.898350  0.911045
# 9  10   0.939626  0.153139  0.660305

# %%
pd.read_csv('df1.csv', usecols=['ID', 'column_1', 'column_2'], index_col='ID')
# Out:
#      column_1  column_2
# ID
# 1   10.000000  0.650789
# 2    0.579455  0.228375
# 3    0.795452  0.442056
# 4    0.491745  0.388145
# 5    0.772243  0.989609
# 6    0.259201  0.986244
# 7    0.362446  0.533233
# 8    0.307099  0.818498
# 9    0.068612  0.911045
# 10   0.939626  0.660305

# %%
pd.read_pickle('df1.pkl')
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.650789  0.857824  0.434486  0.380901  0.490834
# 2    0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 3    0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 4    0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 5    0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 6    0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 7    0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 8    0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 9    0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 10   0.939626  0.660305  0.350960  0.278462  0.153139  0.180558

# %% [markdown]
# ## "Affiancamento" di DataFrame

# %%
pd.concat([df1, df1.reset_index()], axis=1)
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  index  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN    1.0
# 1   10.000000  0.650789  0.857824  0.434486  0.380901  0.490834    2.0
# 2    0.579455  0.228375  0.677056  0.367590  0.193982  0.142684    3.0
# 3    0.795452  0.442056  0.409097  0.784714  0.527606  0.275991    4.0
# 4    0.491745  0.388145  0.958718  0.761051  0.401298  0.336536    5.0
# 5    0.772243  0.989609  0.606257  0.012547  0.746123  0.736742    6.0
# 6    0.259201  0.986244  0.723775  0.201856  0.503041  0.905779    7.0
# 7    0.362446  0.533233  0.508043  0.826672  0.218643  0.867372    8.0
# 8    0.307099  0.818498  0.291330  0.577276  0.211368  0.880437    9.0
# 9    0.068612  0.911045  0.986794  0.993131  0.898350  0.972791   10.0
# 10   0.939626  0.660305  0.350960  0.278462  0.153139  0.180558    NaN
#
#      column_1  column_2  column_3  column_4  column_5  column_6
# 0   10.000000  0.650789  0.857824  0.434486  0.380901  0.490834
# 1    0.579455  0.228375  0.677056  0.367590  0.193982  0.142684
# 2    0.795452  0.442056  0.409097  0.784714  0.527606  0.275991
# 3    0.491745  0.388145  0.958718  0.761051  0.401298  0.336536
# 4    0.772243  0.989609  0.606257  0.012547  0.746123  0.736742
# 5    0.259201  0.986244  0.723775  0.201856  0.503041  0.905779
# 6    0.362446  0.533233  0.508043  0.826672  0.218643  0.867372
# 7    0.307099  0.818498  0.291330  0.577276  0.211368  0.880437
# 8    0.068612  0.911045  0.986794  0.993131  0.898350  0.972791
# 9    0.939626  0.660305  0.350960  0.278462  0.153139  0.180558
# 10        NaN       NaN       NaN       NaN       NaN       NaN
